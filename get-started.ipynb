# %%
from vnstock import Vnstock

# Initialize Vnstock
vnstock = Vnstock()

# Example: Get stock quote for VCI
quote = vnstock.stock(symbol='VCI', source='VCI').quote
print(quote.history(start='2020-01-01', end='2024-05-25'))
